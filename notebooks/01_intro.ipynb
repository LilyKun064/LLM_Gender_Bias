# %%
import numpy as np
import pandas as pd

print("Hello from the LLM gender bias project!")
# Out:
# Hello from the LLM gender bias project!

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# Force-load .env from the correct location
dotenv_path = os.path.join("E:\\LLM_Gender_Bias", "config", ".env")
load_dotenv(dotenv_path)

api_key = os.getenv("OPENAI_API_KEY")
print("Loaded key?", api_key is not None)

client = OpenAI(api_key=api_key)

response = client.responses.create(
    model="gpt-4.1-mini",
    input="Say: 'API working!'",
)

response.output[0].content[0].text
# Out:
# Loaded key? True
# 'API working!'
